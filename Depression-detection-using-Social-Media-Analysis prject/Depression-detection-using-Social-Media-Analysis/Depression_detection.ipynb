# %%
import re
import pandas as pd 
import numpy as np

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import string

# %%
import nltk
import warnings

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
data  = pd.read_csv(r"C:\Users\DELL\Desktop\Project\dataset4.csv" )

# %%
data
# Out:
#      ItemID  Sentiment SentimentSource  \
# 0         1          0    Sentiment140
# 1         2          0    Sentiment140
# 2         3          1    Sentiment140
# 3         4          0    Sentiment140
# 4         5          0    Sentiment140
# 5         6          0    Sentiment140
# 6         7          1    Sentiment140
# 7         8          0    Sentiment140
# 8         9          1    Sentiment140
# 9        10          1    Sentiment140
# 10       11          0    Sentiment140
# 11       12          1    Sentiment140
# 12       13          0    Sentiment140
# 13       14          0    Sentiment140
# 14       15          0    Sentiment140
# 15       16          0    Sentiment140
# 16       17          0    Sentiment140
# 17       18          1    Sentiment140
# 18       19          0    Sentiment140
# 19       20          0    Sentiment140
# 20       21          0    Sentiment140
# 21       22          0    Sentiment140
# 22       23          1    Sentiment140
# 23       24          0    Sentiment140
# 24       25          0    Sentiment140
# 25       26          0    Sentiment140
# 26       27          0    Sentiment140
# 27       28          0    Sentiment140
# 28       29          1    Sentiment140
# 29       30          0    Sentiment140
# ..      ...        ...             ...
# 111     112          0    Sentiment140
# 112     113          1    Sentiment140
# 113     114          1    Sentiment140
# 114     115          1    Sentiment140
# 115     116          0    Sentiment140
# 116     117          1    Sentiment140
# 117     118          1    Sentiment140
# 118     119          0    Sentiment140
# 119     120          0    Sentiment140
# 120     121          0    Sentiment140
# 121     122          0    Sentiment140
# 122     123          0    Sentiment140
# 123     124          0    Sentiment140
# 124     125          0    Sentiment140
# 125     126          0    Sentiment140
# 126     127          0    Sentiment140
# 127     128          1    Sentiment140
# 128     129          1    Sentiment140
# 129     130          0    Sentiment140
# 130     131          0    Sentiment140
# 131     132          0    Sentiment140
# 132     133          0    Sentiment140
# 133     134          1    Sentiment140
# 134     135          0    Sentiment140
# 135     136          0    Sentiment140
# 136     137          0    Sentiment140
# 137     138          1    Sentiment140
# 138     139          1    Sentiment140
# 139     140          0    Sentiment140
# 140     141          0    Sentiment140
#
#                                          SentimentText
# 0                         is so sad for my APL frie...
# 1                       I missed the New Moon trail...
# 2                              omg its already 7:30 :O
# 3              .. Omgaga. Im sooo  im gunna CRy. I'...
# 4             i think mi bf is cheating on me!!!   ...
# 5                    or i just worry too much?
# 6                   Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7           Sunny Again        Work Tomorrow  :-|  ...
# 8          handed in my uniform today . i miss you ...
# 9             hmmmm.... i wonder how she my number @-)
# 10                       I must think about positive..
# 11         thanks to all the haters up in my face a...
# 12                      this weekend has sucked so far
# 13              jb isnt showing in australia any more!
# 14                                ok thats it you win.
# 15       &lt;-------- This is the way i feel right ...
# 16       awhhe man.... I'm completely useless rt no...
# 17       Feeling strangely fine. Now I'm gonna go l...
# 18        HUGE roll of thunder just now...SO scary!!!!
# 19       I just cut my beard off. It's only been gr...
# 20                                Very sad about Iran.
# 21                                       wompppp wompp
# 22       You're the only one who can see this cause...
# 23      &lt;---Sad level is 3. I was writing a mass...
# 24      ...  Headed to Hospitol : Had to pull out o...
# 25      BoRinG   ): whats wrong with him??     Plea...
# 26      can't be bothered. i wish i could spend the...
# 27      Feeeling like shit right now. I really want...
# 28               goodbye exams, HELLO ALCOHOL TONIGHT
# 29      I didn't realize it was THAT deep. Geez giv...
# ..                                                 ...
# 111    Thanks for your definition of throwbie!  Edi...
# 112             Thanks, I need all the help i can get.
# 113                              - that explains alot.
# 114    There's going to be a Heathers sequel.  Wino...
# 115    told not to drink w/my Rx so just gave all t...
# 116    trae is so sweet! He just bought me a new ba...
# 117    True, highly subjective of me there. Tombre ...
# 118                                    u guys knw whyy
# 119                                      very much so
# 120    waahhh now I'm getting sad....miss hub :-'(&...
# 121  --  we were standing out in the pouring rain.....
# 122    Went to get dog from vets, theyve stitched h...
# 123                  where is my picture i feel naked
# 124    Why aren't there any trains going to manches...
# 125   - Why must people be so picky. I mean 6 hours...
# 126    Why Twitter will soon become obsolete? http:...
# 127                                wide awake   NOT!!!
# 128    yeah me too. Its been awful weather here for...
# 129   - You: hi Stranger: HELLO I AM FRANK LAMPARD ...
# 130    you'll always be my one and only...  [12*23*...
# 131                     #3turnoffwords this shit sucks
# 132   #asylm J2 panel is over. Guess it's back to n...
# 133       #poemsunder140 ....started by @shannonelyse1
# 134   #squarespace brighten my bad day! i never win...
# 135   #Susan Boyle didnt win! mh well, diversity wa...
# 136                                          #twenty20
# 137   &lt;--- That is all, and believe me.. it's en...
# 138                             &lt;3 goooood timessss
# 139                             &lt;3 GrAdUaTE 09&lt;3
# 140   &quot; Vandals paint swastikas on home of aut...
#
# [141 rows x 4 columns]

# %%
data.drop(["SentimentSource"], axis = 1, inplace = True)

# %%
data.columns = ['id', 'label', 'tweet']

# %%
data
# Out:
#       id  label                                              tweet
# 0      1      0                       is so sad for my APL frie...
# 1      2      0                     I missed the New Moon trail...
# 2      3      1                            omg its already       O
# 3      4      0               Omgaga  Im sooo  im gunna CRy  I ...
# 4      5      0           i think mi bf is cheating on me      ...
# 5      6      0                  or i just worry too much
# 6      7      1                 Juuuuuuuuuuuuuuuuussssst Chillin
# 7      8      0         Sunny Again        Work Tomorrow       ...
# 8      9      1        handed in my uniform today   i miss you ...
# 9     10      1           hmmmm     i wonder how she my number
# 10    11      0                      I must think about positive
# 11    12      1        thanks to all the haters up in my face a...
# 12    13      0                     this weekend has sucked so far
# 13    14      0             jb isnt showing in australia any more
# 14    15      0                               ok thats it you win
# 15    16      0       lt          This is the way i feel right ...
# 16    17      0      awhhe man     I m completely useless rt no...
# 17    18      1      Feeling strangely fine  Now I m gonna go l...
# 18    19      0       HUGE roll of thunder just now   SO scary
# 19    20      0      I just cut my beard off  It s only been gr...
# 20    21      0                               Very sad about Iran
# 21    22      0                                      wompppp wompp
# 22    23      1      You re the only one who can see this cause...
# 23    24      0      lt    Sad level is    I was writing a mass...
# 24    25      0          Headed to Hospitol   Had to pull out o...
# 25    26      0     BoRinG      whats wrong with him       Plea...
# 26    27      0     can t be bothered  i wish i could spend the...
# 27    28      0     Feeeling like shit right now  I really want...
# 28    29      1              goodbye exams  HELLO ALCOHOL TONIGHT
# 29    30      0     I didn t realize it was THAT deep  Geez giv...
# ..   ...    ...                                                ...
# 111  112      0    Thanks for your definition of throwbie   Edi...
# 112  113      1             Thanks  I need all the help i can get
# 113  114      1                                that explains alot
# 114  115      1    There s going to be a Heathers sequel   Wino...
# 115  116      0    told not to drink w my Rx so just gave all t...
# 116  117      1    trae is so sweet  He just bought me a new ba...
# 117  118      1    True  highly subjective of me there  Tombre ...
# 118  119      0                                    u guys knw whyy
# 119  120      0                                      very much so
# 120  121      0    waahhh now I m getting sad    miss hub      ...
# 121  122      0      we were standing out in the pouring rain  ...
# 122  123      0    Went to get dog from vets  theyve stitched h...
# 123  124      0                  where is my picture i feel naked
# 124  125      0    Why aren t there any trains going to manches...
# 125  126      0     Why must people be so picky  I mean   hours...
# 126  127      0    Why Twitter will soon become obsolete  http ...
# 127  128      1                                wide awake   NOT
# 128  129      1    yeah me too  Its been awful weather here for...
# 129  130      0     You  hi Stranger  HELLO I AM FRANK LAMPARD ...
# 130  131      0    you ll always be my one and only            ...
# 131  132      0                     # turnoffwords this shit sucks
# 132  133      0   #asylm J  panel is over  Guess it s back to n...
# 133  134      1       #poemsunder        started by  shannonelyse
# 134  135      0   #squarespace brighten my bad day  i never win...
# 135  136      0   #Susan Boyle didnt win  mh well  diversity wa...
# 136  137      0                                          #twenty
# 137  138      1    lt     That is all  and believe me   it s en...
# 138  139      1                              lt   goooood timessss
# 139  140      0                              lt   GrAdUaTE    lt
# 140  141      0    quot  Vandals paint swastikas on home of aut...
#
# [141 rows x 3 columns]

# %%
data['tweet'] = data['tweet'].str.replace("[^a-zA-Z#]", " ")

# %%
tokenized_tweet = data['tweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0                  [is, so, sad, for, my, APL, friend]
# 1                 [I, missed, the, New, Moon, trailer]
# 2                               [omg, its, already, O]
# 3    [Omgaga, Im, sooo, im, gunna, CRy, I, ve, been...
# 4       [i, think, mi, bf, is, cheating, on, me, T, T]
# Name: tweet, dtype: object

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
tokenized_tweet.head()
# Out:
# 0                  [is, so, sad, for, my, apl, friend]
# 1                   [I, miss, the, new, moon, trailer]
# 2                                [omg, it, alreadi, O]
# 3    [omgaga, Im, sooo, im, gunna, cri, I, ve, been...
# 4          [i, think, mi, bf, is, cheat, on, me, T, T]
# Name: tweet, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])

data['tweet'] = tokenized_tweet

# %%
data.head()
# Out:
#    id  label                                              tweet
# 0   1      0                        is so sad for my apl friend
# 1   2      0                        I miss the new moon trailer
# 2   3      1                                   omg it alreadi O
# 3   4      0  omgaga Im sooo im gunna cri I ve been at thi d...
# 4   5      0                   i think mi bf is cheat on me T T

# %%
all_words = ' '.join([text for text in data['tweet']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-25c3a89aa0f1> in <module>
#       1 all_words = ' '.join([text for text in data['tweet']])
# ----> 2 from wordcloud import WordCloud
#       3 wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
#       4
#       5 plt.figure(figsize=(10, 7))
#
# ModuleNotFoundError: No module named 'wordcloud'
